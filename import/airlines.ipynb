# %% [markdown]
# # Airlines
#
# Obtained from https://en.wikipedia.org/wiki/List_of_airline_codes. Then exported as csv.
# Not ideal because utf8, inconsistancies etc...
#
# Some images from https://flightaware.com/live/fleet/{3 character code}
#
# Assumes directory present with images. These will be references in the export

# %%
import csv
import unicodedata
import requests
import os

# %%
image_path = '../lib/airline-logos/images/'
download_logos = False

# %% [markdown]
# Read the airports from the scv file

# %%
with open('airlines.csv', newline='') as csvfile:
    airlines_csv = csv.reader(csvfile, delimiter=',', quoting=csv.QUOTE_NONE)
    airlines = []

    # IATA	ICAO	Airline	Call sign	Country/Region	Comments
    for row in airlines_csv:
        icao = row[1]
        if not icao or icao == 'n/a':
            continue

        if (len(row) == 6):
            airlines.append(
                {'iata': row[0], 'icao': icao, 'airline': row[2], 'callsign': row[3], 'country': row[4]})

        if (len(row) == 7):
            # airline has often a , example: ,ALC,Southern Jersey Airways, Inc.,ACOM,United States,
            airlines.append(
                {'iata': row[0], 'icao': icao, 'airline': row[2] + ',' + row[3], 'callsign': row[4], 'country': row[5], 'comments': row[6]})


#print(airlines)

# %% [markdown]
# Sort the list on the column 'icao'

# %%
airlines.sort(key=lambda v: v['icao'])

# %% [markdown]
# Download logos

# %%
if download_logos:
    for airline in airlines:
        logo_path = image_path + airline['icao'] + '.png'
        # Do not overwrite
        if os.path.exists(logo_path):
            continue

        logo_url = 'https://e0.flightcdn.com/images/airline_logos/90p/'+ airline['icao'] + '.png'
        #logo_url = 'https://flightaware.com/live/fleet/' + key + '.png'
        request = requests.get(logo_url, allow_redirects=True)
        if request.status_code == 200:
            open(logo_path, 'wb').write(request.content)
            print ('Downloaded ' + logo_url)

# %% [markdown]
# Generate the output

# %%
for airline in airlines:
    logo_path = image_path + airline['icao'] + '.png'
    logo = '&airline_logo_' + airline['icao'] if os.path.exists(logo_path) else 'nullptr'

    values = ["\"" + airline['icao'] + "\"", "\"" + airline['callsign']+"\"", "\"" + airline['airline']+"\"", "\"" + airline['country'] +"\"", logo]
    line = "{ " + ", ".join(values) + "}"
    print(unicodedata.normalize('NFKD', line).encode('ascii', errors='ignore').decode('ascii'))
# Out:
# { "AAA", "ANSETT", "Ansett Australia", "Australia", &airline_logo_AAA}
# { "AAB", "ABG", "Abelag Aviation", "Belgium", nullptr}
# { "AAC", "ARMYAIR", "Army Air Corps", "United Kingdom", nullptr}
# { "AAD", "SUNRISE", "Aero Aviation Centre Ltd.", "Canada", nullptr}
# { "AAD", "Ambassador", "Mann Air Ltd", "United Kingdom", nullptr}
# { "AAE", "AIR EAST", "Astec Air East", "United States", nullptr}
# { "AAE", "ARIZONA", "Arizona Air", "United States", nullptr}
# { "AAE", "ARIZONA", "Western Express Air", "United States", nullptr}
# { "AAF", "AIGLE AZUR", "Aigle Azur", "France", nullptr}
# { "AAG", "ATLANTIC", "Atlantic Flight Training", "United Kingdom", nullptr}
# { "AAH", "ALOHA", "Aloha Air Cargo", "United States", &airline_logo_AAH}
# { "AAH", "ALOHA", "Aloha Airlines", "United States", &airline_logo_AAH}
# { "AAI", "BOREALIS", "Air Aurora", "United States", nullptr}
# { "AAJ", "AIR ALMA", "Air Alma", "Canada", nullptr}
# { "AAJ", "ALFA SUDAN", "Alfa Airlines", "Sudan", nullptr}
# { "AAK", "ALASKA ISLAND", "Alaska Island Air", "United States", nullptr}
# { "AAL", "AMERICAN", "American Airlines", "United States", &airline_logo_AAL}
# { "AAM", "", "Aim Air", "Moldova", &airline_logo_AAM}
# { "AAN", "AMSTEL", "Amsterdam Airlines", "Netherlands", nullptr}
# { "AAN", "ANDALUSAIR", "Andalusair", "Spain", nullptr}
# { "AAN", "OASIS", "Oasis International AirlinesNow assigned to Boliviana de Aviacion (BoA)", "Spain", nullptr}
# { "AAO", "ATLANTIS AIR", "Atlantis Airlines (USA)", "United States", nullptr}
# { "AAP", "AEROVISTA GROUP", "Aerovista Airlines", "Kyrgyzstan", nullptr}
# { "AAP", "ASTRO AIR", "Astro Air International", "Philippines", nullptr}
# { "AAP", "ARABASCO", "Arabasco Air Services", "Saudi Arabia", nullptr}
# { "AAQ", "LIAISON", "Air Alliance", "Canada", nullptr}
# { "AAQ", "COPTERLINE", "Copterline", "Finland", nullptr}
# { "AAR", "ASIANA", "Asiana Airlines", "Republic of Korea", &airline_logo_AAR}
# { "AAR", "PATRIOT", "Americ Air", "United States", &airline_logo_AAR}
# { "AAS", "AL-ASS", "Askari Aviation", "Pakistan", nullptr}
# { "AAS", "Aviaservice", "Airtransservice", "Russia", nullptr}
# { "AAS", "AIR SERVICES", "Austrian Air Services", "Austria", nullptr}
# { "AAS", "", "Sunshine Airlines", "", nullptr}
# { "AAT", "", "Air Central Asia", "Kyrgyzstan", nullptr}
# { "AAT", "Austria", "Austrian Airtransport,AUSTRIAN CHARTER", "defunct; former IATA code: U8", nullptr}
# { "AAU", "AUSTASIA", "Australia Asia Airlines", "Australia", nullptr}
# { "AAV", "ASTRO-PHIL", "Astro Air International", "United States", nullptr}
# { "AAV", "", "Aly Aviation", "United Kingdom", nullptr}
# { "AAW", "AFRIQIYAH", "Afriqiyah Airways", "Libya", nullptr}
# { "AAW", "AUSTIN", "Austin Airways", "Canada", nullptr}
# { "AAW", "", "Aberdeen Airways", "United Kingdom", nullptr}
# { "AAW", "ALMETA AIR", "Almeta Air", "Austria", nullptr}
# { "AAX", "AFREX", "Afric'air Express", "Cte d'Ivoire", nullptr}
# { "AAX", "ADVANCE AVIATION", "Advance Aviation", "Thailand", nullptr}
# { "AAY", "ALLEGIANT", "Allegiant Air", "United States", &airline_logo_AAY}
# { "AAZ", "ANGUS", "Angus Aviation", "Canada", nullptr}
# { "AAZ", "", "Asian Air", "Kyrgyzstan", nullptr}
# { "ABA", "ARTEM-AVIA", "Artem-Avia", "Ukraine", nullptr}
# { "ABA", "AEROBETA", "Aero-Beta", "Germany", nullptr}
# { "ABA", "Aerobeta", "Aero-Beta", "Germany", nullptr}
# { "ABB", "AFRICAN BUSINESS", "African Business and Transportations", "Democratic Republic of the Congo", nullptr}
# { "ABD", "ATLANTA", "Air Atlanta Icelandic", "Iceland", &airline_logo_ABD}
# { "ABE", "ABAN", "Aban Air", "Iran", nullptr}
# { "ABE", "ARBERIA AIRLINES", "Arberia Airlines", "Albania", nullptr}
# { "ABF", "SKYWINGS", "Aerial Oy", "Finland", nullptr}
# { "ABG", "ABAKAN-AVIA", "Abakan-Avia", "Russia", nullptr}
# { "ABH", "", "Hokuriki-Koukuu Company", "Japan", nullptr}
# { "ABI", "Anair", "Antigua and Barbuda Airways", "Antigua and Barbuda", nullptr}
# { "ABJ", "", "Abaet Linhas Areas", "Brazil", nullptr}
# { "ABK", "Canada", "Alberta Citylink,ALBERTA CITYLINK", "defunct", nullptr}
# { "ABL", "AIRCOACH", "Air BC", "Canada", nullptr}
# { "ABL", "AIR BUSAN", "Air Busan", "Republic of Korea", nullptr}
# { "ABM", "ALBATROS ESPANA", "Aero Albatros", "Spain", nullptr}
# { "ABN", "", "Air Fret Senegal", "Senegal", nullptr}
# { "ABN", "AIR ALBANIA", "Air Albania", "Albania", nullptr}
# { "ABO", "AEROEXPRESO", "APSA Colombia", "Colombia", nullptr}
# { "ABP", "BAIR", "ABS Jets", "Czech Republic", nullptr}
# { "ABQ", "PAKBLUE", "Airblue", "Pakistan", nullptr}
# { "ABR", "Ireland", "ASL Airlines Ireland,CONTRACT", "Former IATA Code: AG; former names: Hunting Air Cargo Airlines", &airline_logo_ABR}
# { "ABR", "AIRBRIDGE", "Air Bridge Carriers", "United Kingdom", &airline_logo_ABR}
# { "ABS", "AIR CENTRAL", "Air Central", "United States", nullptr}
# { "ABS", "ATHABASKA", "Transwest Air", "Canada", nullptr}
# { "ABT", "AIR BROUSSE", "Air Brousse", "Canada", nullptr}
# { "ABT", "AMBITION", "Ambeo", "United Kingdom", nullptr}
# { "ABU", "AEROBUENO", "Aerovas Bueno", "Colombia", nullptr}
# { "ABU", "", "Eagle Aviation Services", "United States", nullptr}
# { "ABV", "ANTRAK", "Antrak Air", "Ghana", nullptr}
# { "ABW", "AIRBRIDGE CARGO", "AirBridge Cargo", "Russia", &airline_logo_ABW}
# { "ABX", "United States", "Airborne Express,ABEX", "August 14", &airline_logo_ABX}
# { "ABX", "United States", "ABX Air,ABEX", "August 15", &airline_logo_ABX}
# { "ABY", "ARABIA", "Air Arabia", "United Arab Emirates", nullptr}
# { "ABZ", "ISLAND LIFEFLIGHT", "Air Ambulance Services", "Bahamas", nullptr}
# { "ABZ", "ATA-BRAZIL", "ATA Brasil", "Brazil", nullptr}
# { "ACA", "AIR CANADA", "Air Canada", "Canada", &airline_logo_ACA}
# { "ACB", "AFRICARGO", "African Cargo Services", "Kenya", nullptr}
# { "ACC", "", "Airspeed Charter", "Jamaica", nullptr}
# { "ACC", "", "Avcard Services", "United Kingdom", nullptr}
# { "ACD", "ACADEMY", "Academy Airlines", "United States", nullptr}
# { "ACE", "", "Air Charter Express", "Ghana", nullptr}
# { "ACE", "Fastcargo", "Race Cargo Airlines", "Ghana", nullptr}
# { "ACF", "FORCAN", "Centro de Formacin Aeronutica de Canarias", "Spain", nullptr}
# { "ACG", "AIR PARTNER", "Air Partner", "United Kingdom", nullptr}
# { "ACH", "AIR PLUS", "Air Cargo Plus", "Liberia", nullptr}
# { "ACI", "AIRCALIN", "Air Caledonie International", "France", nullptr}
# { "ACJ", "AVICHARTER", "Avicon", "Kenya", nullptr}
# { "ACK", "ACK AIR", "Nantucket Airlines", "United States", nullptr}
# { "ACL", "SPADA", "Itali Airlines", "Italy", nullptr}
# { "ACM", "WEST CAL", "Air Caledonia", "Canada", nullptr}
# { "ACN", "AEROCENTRO", "Central American Airlines", "Nicaragua", nullptr}
# { "ACP", "ASTRAL CARGO", "Astral Aviation", "Kenya", nullptr}
# { "ACQ", "", "Aryan Cargo Express", "India", nullptr}
# { "ACQ", "AERO CONTINENTE", "Nuevo Continente", "Peru", nullptr}
# { "ACR", "AEROCENTER", "Aerocenter, Escuela de Formacin de Pilotos Privados de Avin", "Spain", nullptr}
# { "ACS", "", "Air Cess", "Liberia", nullptr}
# { "ACS", "AIRCRAFT SALES", "Aircraft Sales and Services", "Pakistan", nullptr}
# { "ACT", "AMERICAN CHECK", "Flight Line", "United States", nullptr}
# { "ACU", "AFRISPIRIT", "Air Cargo Transportation System", "Kenya", nullptr}
# { "ACV", "", "Air Charter Service", "United Kingdom", nullptr}
# { "ACW", "AIR CADET", "Royal Air Force", "United Kingdom", nullptr}
# { "ACX", "LOADMASTER", "Air Cargo Germany", "Germany", nullptr}
# { "ACX", "PARAIR", "Air Charters", "Canada", nullptr}
# { "ACY", "ATLAS CARGOLINES", "Atlas Cargo Airlines", "Morocco", nullptr}
# { "ADA", "AUSCAL", "Airservices Australia", "Australia", nullptr}
# { "ADB", "ANTONOV BUREAU", "Antonov Airlines", "Ukraine", nullptr}
# { "ADC", "ATLAN-DOMINICAN", "Air Atlantic Dominicana", "Dominican Republic", nullptr}
# { "ADC", "AD ASTRA", "AD Astra Executive Charter", "Poland", nullptr}
# { "ADD", "", "Advanced Air Co.", "Japan", nullptr}
# { "ADD", "", "Advanced Air Co.", "Japan", nullptr}
# { "ADE", "Albania", "Ada Air,ADA AIR", "defunct", nullptr}
# { "ADF", "ADE AVIACION", "Ade, Aviacin Deportiva", "Spain", nullptr}
# { "ADG", "AEREA TRAINING", "Aerea Flying Training Organization", "Spain", nullptr}
# { "ADI", "AUDELI", "Audeli Air", "Spain", nullptr}
# { "ADJ", "ABICAR", "Abidjan Air Cargo", "Cte d'Ivoire", nullptr}
# { "ADK", "ADCO", "ADC Airlines", "Nigeria", nullptr}
# { "ADL", "COTSWOLD", "Aero Dynamics", "United Kingdom", nullptr}
# { "ADM", "Dominican Republic", "Dominair,DOMINAIR", "defunct; former IATA code: SS; former name: Aerolneas Dominicanas", nullptr}
# { "ADN", "AERODIENST", "Aero-Dienst", "Germany", nullptr}
# { "ADO", "AIR DO", "Air Do", "Japan", nullptr}
# { "ADO", "AIR DO", "AIRDO", "Japan", nullptr}
# { "ADP", "AERODIPLOMATIC", "Aerodiplomatic", "Mexico", nullptr}
# { "ADQ", "AIR DATA", "Avion Taxi", "Canada", nullptr}
# { "ADR", "ADRIA", "Adria Airways", "Slovenia", nullptr}
# { "ADS", "SONORAV", "Aviones de Sonora", "Mexico", nullptr}
# { "ADT", "AIR DORVAL", "Air Dorval", "Canada", nullptr}
# { "ADT", "ARRENDA-TRANS", "Arrendaminetos y Transportes Turisticos", "Mexico", nullptr}
# { "ADU", "AIRDEAL", "Airdeal Oy", "Finland", nullptr}
# { "ADV", "ADVANCE", "Advance Air Charters", "Canada", nullptr}
# { "ADV", "ADVANCED", "Advanced Flight Training", "United Kingdom", nullptr}
# { "ADW", "AIR ANDAMAN", "Air Andaman", "Thailand", nullptr}
# { "ADW", "", "ADC Airways", "Lebanon", nullptr}
# { "ADX", "ANDAX", "Anderson Aviation", "United States", nullptr}
# { "ADY", "AERODYNE", "Aerodyne", "United States", nullptr}
# { "ADZ", "", "Avio Delta", "Bulgaria", nullptr}
# { "AE", "", "Air Ceylon", "Sri Lanka", nullptr}
# { "AEA", "EUROPA", "Air Europa", "Spain", &airline_logo_AEA}
# { "AEB", "AEROBEN", "Aero Benin", "Benin", nullptr}
# { "AEC", "AEROCESAR", "Aerocsar", "Colombia", nullptr}
# { "AED", "", "Aerotrans Airlines", "Russia", nullptr}
# { "AED", "AIE EXPERIENCE", "Aie Experience Flight", "United Kingdom", nullptr}
# { "AED", "Aernspa", "Aernord", "Italy", nullptr}
# { "AEE", "AEGEAN", "Aegean Airlines", "Greece", &airline_logo_AEE}
# { "AEF", "", "Aerea", "Spain", nullptr}
# { "AEG", "FUMIGACIONES SAM", "Aerofumigaciones Sam", "Chile", nullptr}
# { "AEG", "AIR EAST", "Air East", "Slovakia", nullptr}
# { "AEH", "AEROCUTTER", "Aero4m", "Slovenia", nullptr}
# { "AEH", "AVEX", "Aviaexpress", "Hungary", nullptr}
# { "AEI", "INTERAM", "Aeroexpreso Interamericano", "Colombia", nullptr}
# { "AEI", "POLISH BIRD", "Air Italy Polska", "Poland", nullptr}
# { "AEJ", "KHAKI EXPRESS", "Air Express", "Tanzania", nullptr}
# { "AEK", "AEROCON", "Aerocon", "Bolivia", nullptr}
# { "AEK", "ACORISA", "Aero Costa Rica", "Costa Rica", nullptr}
# { "AEL", "AIR EUROPE", "Air Europe Italy", "Italy", nullptr}
# { "AEM", "AEROMADRID", "Aero Madrid", "Spain", nullptr}
# { "AEN", "AIR ENTERPRISE", "Air Enterprise", "France", nullptr}
# { "AEN", "Greece", "Aeroland Airways,", "defunct", nullptr}
# { "AEO", "AERO OCCIDENTE", "Aeroservicios Ejecutivos Del Occidente", "Mexico", nullptr}
# { "AEP", "AEROTEC", "Aerotec Escuela de Pilotos", "Spain", nullptr}
# { "AEQ", "LUNA", "Air Express", "Sweden", nullptr}
# { "AER", "ACE AIR", "Alaska Central Express", "United States", nullptr}
# { "AES", "ACES", "ACES Colombia", "Colombia", nullptr}
# { "AES", "AEROPARAGUAY", "Aerosur Paraguay", "Paraguay", nullptr}
# { "AET", "AERO PALMA", "Aero-Palma", "Spain", nullptr}
# { "AET", "AEROTIME", "Aerotime", "United Kingdom", nullptr}
# { "AEU", "United Kingdom", "Astraeus,FLYSTAR", "defunct", nullptr}
# { "AEV", "AEROVENTAS", "Aeroventas", "Mexico", nullptr}
# { "AEW", "AEROSVIT", "Aerosvit Airlines", "Ukraine", nullptr}
# { "AEX", "AVCO", "Airway Express", "United States", nullptr}
# { "AEY", "AIR ITALY", "Air Italy", "Italy", nullptr}
# { "AEZ", "AERIAL TRANZ", "Aerial Transit", "United States", nullptr}
# { "AFA", "BLUE ALFA", "Alfa Air", "Czech Republic", nullptr}
# { "AFB", "AMERICAN FALCON", "American Falcon", "Argentina", nullptr}
# { "AFC", "AFRICAN WEST", "African West Air", "Senegal", nullptr}
# { "AFD", "AIRFED", "Panorama Flight Service", "United States", nullptr}
# { "AFE", "AIRFAST", "Airfast Indonesia", "Indonesia", nullptr}
# { "AFF", "AFRIWAYS", "Africa Airways", "Benin", nullptr}
# { "AFG", "ARIANA", "Ariana Afghan Airlines", "Afghanistan", nullptr}
# { "AFH", "FECTO", "Air Fecteau", "Canada", nullptr}
# { "AFI", "AFRICAWORLD", "Africaone", "The Gambia", nullptr}
# { "AFJ", "JAMBO", "Alliance Air", "Uganda", nullptr}
# { "AFK", "AFRICA LINKS", "Africa Air Links", "Sierra Leone", nullptr}
# { "AFL", "AEROFLOT", "Aeroflot Russian Airlines", "Russia", &airline_logo_AFL}
# { "AFM", "EPIC AIR", "AEROSPEED FORMATION ET MAINTENANCE", "France", nullptr}
# { "AFN", "SIMBA", "African International Airlines", "Lesotho", nullptr}
# { "AFO", "AERO EMPRESA", "Aero Empresa Mexicana", "Mexico", nullptr}
# { "AFP", "PORTUGUESE AIR FORCE", "Portuguese Air Force", "Portugal", nullptr}
# { "AFQ", "ALBA", "Alba Servizi Aerotrasporti", "Italy", nullptr}
# { "AFR", "AIRFRANS", "Air France", "France", &airline_logo_AFR}
# { "AFS", "", "Air Data", "United Kingdom", nullptr}
# { "AFU", "Gambia", "Afrinat International Airlines,AFRINAT", "defunct", nullptr}
# { "AFV", "AFRIQUE VACANCE", "Air Afrique Vacancies", "Cte d'Ivoire", nullptr}
# { "AFW", "AFRAIR", "Afrique Regional Airways", "Cte d'Ivoire", nullptr}
# { "AFW", "BLACKSTAR", "Africa World Airlines", "Ghana", nullptr}
# { "AFX", "", "Airfreight Express", "United Kingdom", nullptr}
# { "AFY", "AFRICA CHARTERED", "Africa Chartered Services", "Nigeria", nullptr}
# { "AFZ", "AFREIGHT", "Africa Freight Services", "Zambia", nullptr}
# { "AGA", "GEOLINE", "AG Air", "Georgia", nullptr}
# { "AGA", "", "Aeronaves Del Centro", "Venezuela", nullptr}
# { "AGB", "", "Air Service Gabon", "Gabon", nullptr}
# { "AGC", "AGRICO", "Arab Agricultural Aviation Company", "Egypt", nullptr}
# { "AGE", "AEROANGEL", "Servicios Areos de Los ngeles", "Mexico", nullptr}
# { "AGF", "ATLANTIC GULF", "Atlantic Gulf Airlines", "United States", nullptr}
# { "AGG", "ALGOMA", "Algoma Airways", "Canada", nullptr}
# { "AGH", "ALTAGNA", "Altagna", "France", nullptr}
# { "AGI", "ANGELES AMERICA", "Aereo Transportes Los Angeles de America", "Mexico", nullptr}
# { "AGM", "AIR GUAM", "Air Guam", "United States", nullptr}
# { "AGM", "ANGEL MED", "Aviation West Charters", "United States", nullptr}
# { "AGN", "GOLF NOVEMBER", "Air Gabon", "Gabon", nullptr}
# { "AGO", "ANGOLA CHARTER", "Angola Air Charter", "Angola", nullptr}
# { "AGP", "AIR TARA", "AERFI Group", "Ireland", nullptr}
# { "AGQ", "GALASERVICE", "Aerogala", "Chile", nullptr}
# { "AGR", "AGRICULTURE", "United States Department Of Agriculture", "United States", nullptr}
# { "AGT", "AMADEUS", "Amadeus IT Group", "Spain", nullptr}
# { "AGU", "SARMA", "Angara Airlines", "Russia", nullptr}
# { "AGV", "AIR GLACIERS", "Air Glaciers", "Switzerland", nullptr}
# { "AGW", "Gambia", "Aero Gambia,AERO GAMBIA", "defunct", nullptr}
# { "AGX", "GENEX", "Aviogenex", "Serbia", nullptr}
# { "AGY", "FLIGHT GROUP", "Aero Flight Service", "United States", nullptr}
# { "AGZ", "AGROLET", "Agrolet-Mci", "Slovakia", nullptr}
# { "AHA", "AIR ALPHA", "Air Alpha Greenland", "Denmark", nullptr}
# { "AHC", "AZALAVIACARGO", "Azal Avia Cargo", "Azerbaijan", nullptr}
# { "AHD", "AIRHANDLING", "Czech Air Handling", "Czech Republic", nullptr}
# { "AHE", "AIRPORT HELICOPTER", "Airport Helicopter Basel, Muller & Co.", "Switzerland", nullptr}
# { "AHF", "ASPEN", "Aspen Helicopters", "United States", nullptr}
# { "AHG", "AEROCHAGO", "Aerochago Airlines", "Dominican Republic", nullptr}
# { "AHH", "AIRHOLD", "Airplanes Holdings", "Ireland", nullptr}
# { "AHI", "AEROCHISA", "Servicios Areos de Chihuahua Aerochisa", "Mexico", nullptr}
# { "AHK", "AIR HONG KONG", "Air Hong Kong", "Hong Kong", nullptr}
# { "AHL", "HIDALGO", "Aerolneas Hidalgo", "Mexico", nullptr}
# { "AHM", "AIR HURON", "Garrison Aviation", "Canada", nullptr}
# { "AHN", "AIR HUNGARIA", "Air Hungaria", "Hungary", nullptr}
# { "AHO", "AIR HAMBURG", "Air Hamburg", "Germany", &airline_logo_AHO}
# { "AHP", "AEROCHIAPAS", "Aerochiapas", "Mexico", nullptr}
# { "AHR", "ADRIATIC", "Air Adriatic", "Croatia", nullptr}
# { "AHS", "HIGH SKY", "AHS Air International", "Pakistan", nullptr}
# { "AHS", "AIRSAR", "Air Viggi San Raffaele", "Italy", nullptr}
# { "AHT", "HELIAPRA", "HTA Helicopteros", "Portugal", nullptr}
# { "AHU", "ABC HUNGARY", "ABC Air Hungary", "Hungary", nullptr}
# { "AHW", "AEROMIST", "Aeromist-Kharkiv", "Ukraine", nullptr}
# { "AHY", "AZAL", "Azerbaijan Airlines", "Azerbaijan", &airline_logo_AHY}
# { "AIA", "AVIES", "Avies", "Estonia", nullptr}
# { "AIB", "AIRBUS INDUSTRIE", "Airbus Industrie", "France", nullptr}
# { "AIC", "AIRINDIA", "Air IndiaLimited", "India", &airline_logo_AIC}
# { "AID", "CENTURY AIRBIRD", "Christian Konig - Century Airbirds", "Austria", nullptr}
# { "AIE", "AIR INUIT", "Air Inuit", "Canada", nullptr}
# { "AIF", "", "Compaa Area de Valencia", "Spain", nullptr}
# { "AIG", "", "Air Inter Gabon", "Gabon", nullptr}
# { "AIH", "AIR INCHEON", "Air Incheon", "South Korea", nullptr}
# { "AII", "INTEGRA", "Air Integra", "Canada", nullptr}
# { "AIJ", "ABC Aerolineas", "Interjet", "Mexico", &airline_logo_AIJ}
# { "AIJ", "ABC AEROLINEAS", "ABC Aerolneas", "Mexico", &airline_logo_AIJ}
# { "AIJ", "ABC AEROLINEAS", "Interjet", "Mexico", &airline_logo_AIJ}
# { "AIK", "AFRICAN AIRLINES", "African AirlinesInternational Limited", "Kenya", nullptr}
# { "AIL", "AIR ILLINOIS", "Air Illinois", "United States", nullptr}
# { "AIM", "PIJO", "Trabajos Areos Murcianos", "Spain", nullptr}
# { "AIN", "FLY CARGO", "African International Airways", "Swaziland", nullptr}
# { "AIO", "AIR CHIEF", "Chief of Staff,United States Air Force", "United States", nullptr}
# { "AIO", "AIR CHIEF", "United States Air Force", "United States", nullptr}
# { "AIP", "ALPINE AIR", "Alpine Air Express", "United States", nullptr}
# { "AIQ", "THAI ASIA", "Thai AirAsia", "Thailand", nullptr}
# { "AIR", "AIRLIFT", "Airlift International", "United States", nullptr}
# { "AIS", "SURESTE", "Air Sureste", "Spain", &airline_logo_AIS}
# { "AIT", "", "Airest", "Estonia", nullptr}
# { "AIU", "ALIA", "Alicante Internacional Airlines", "Spain", nullptr}
# { "AIV", "AIRVIAS", "Airvias S/A Linhas Areas", "Brazil", nullptr}
# { "AIW", "TARTAN", "Atlantic Island Airways", "Canada", nullptr}
# { "AIX", "CRUISER", "Aircruising Australia", "Australia", nullptr}
# { "AIY", "AIRCREW", "Aircrew Check and Training Australia", "Australia", nullptr}
# { "AIZ", "ARKIA", "Arkia Israel Airlines", "Israel", nullptr}
# { "AJA", "AFGHAN JET", "Afghan Jet International Airlines", "Afghanistan", nullptr}
# { "AJB", "AERO JBR", "Aero JBR", "Mexico", nullptr}
# { "AJC", "BAR HARBOR", "Bar Harbor Airlines", "United States", nullptr}
# { "AJE", "JET EXPRESS", "Aero Jet Express", "Mexico", nullptr}
# { "AJF", "AVIACONSULT", "Avia Consult Flugbetriebs", "Austria", nullptr}
# { "AJH", "ALJARAFE", "Aeroaljarafe", "Spain", nullptr}
# { "AJI", "AMERISTAR", "Ameristar Jet Charter", "United States", nullptr}
# { "AJJ", "ATLANTIC JET", "A2 Jet Leasing", "United States", nullptr}
# { "AJK", "BAMBI", "Allied Air", "Nigeria", nullptr}
# { "AJM", "JAMAICA", "Air Jamaica", "Jamaica", &airline_logo_AJM}
# { "AJO", "AEROEXO", "Aero Ejecutivo", "Mexico", nullptr}
# { "AJP", "AEROJETS", "Aero Jets Corporativos", "Mexico", nullptr}
# { "AJR", "JET MONGOLIA", "A-Jet Aviation Company", "Mongolia", nullptr}
# { "AJS", "AEROEJECUTIVOS", "Aeroejecutivos Colombia", "Colombia", nullptr}
# { "AJT", "AMERIJET", "Amerijet International", "United States", &airline_logo_AJT}
# { "AJU", "AIRJETSUL", "Air Jetsul", "Portugal", nullptr}
# { "AJV", "AYJAY CARGO", "ANA & JP Express", "Japan", nullptr}
# { "AJW", "ALPHAJET", "Alpha Jet International", "United States", nullptr}
# { "AJX", "AIR JAPAN", "Air Japan", "Japan", nullptr}
# { "AJY", "Cyprus", "AJet,AYJET", "defunct", nullptr}
# { "AKA", "", "Air Korea Co. Ltd.", "Republic of Korea", nullptr}
# { "AKB", "KARAB", "Aktjubavia", "Kazakhstan", nullptr}
# { "AKC", "ARCA", "Arca Aerovas Colombianas Ltda.", "Colombia", nullptr}
# { "AKF", "ANIKAY", "Anikay Air Company", "Kyrgyzstan", nullptr}
# { "AKG", "GRIFTER", "No. 84 Squadron RAF", "United Kingdom", nullptr}
# { "AKH", "AKHAL", "Akhal", "Turkmenistan", nullptr}
# { "AKI", "", "Ibk-Petra", "Sudan", nullptr}
# { "AKK", "AKLAK", "Aklak Air", "Canada", nullptr}
# { "AKL", "", "Air Kiribati", "Kiribati", nullptr}
# { "AKM", "MAKAIR", "Mak Air", "Kazakhstan", nullptr}
# { "AKN", "ALKAN AIR", "Alkan Air", "Canada", nullptr}
# { "AKR", "AERO CLINKER", "Aero Clinker", "Mexico", nullptr}
# { "AKT", "ARCTIC", "Canadian North", "Canada", nullptr}
# { "AKT", "AVIAKARAT", "Karat", "Russia", nullptr}
# { "AKW", "ANGKORWAYS", "Angkor Airways", "Cambodia", nullptr}
# { "AKX", "ALFA WING", "Air Nippon Network Co. Ltd.", "Japan", nullptr}
# { "AKY", "YAK-SERVICE", "Yak-Service", "Russia", nullptr}
# { "AKZ", "ABSOLUTE", "AK Navigator LLC", "Kazakhstan", nullptr}
# { "ALB", "ALBATROS", "Aero Albatros", "Mexico", nullptr}
# { "ALC", "ACOM", "Southern Jersey Airways, Inc.", "United States", nullptr}
# { "ALD", "ALBION", "Albion Aviation", "United Kingdom", nullptr}
# { "ALE", "AEROALAS", "Aeroalas Colombia", "Colombia", nullptr}
# { "ALF", "ACEFORCE", "Allied Command Europe (Mobile Force)", "Belgium", nullptr}
# { "ALG", "AIRLOG", "Air Logistics", "United States", nullptr}
# { "ALJ", "ALPIN HELI", "Heli Ambulance Team", "Austria", nullptr}
# { "ALK", "SRILANKAN", "SriLankan Airlines", "Sri Lanka", &airline_logo_ALK}
# { "ALK", "SRILANKAN", "SriLankan Airlines", "Sri Lanka", &airline_logo_ALK}
# { "ALL", "VALLARTA", "Aerovallarta", "Mexico", nullptr}
# { "ALM", "ANTILLEAN", "Air ALM", "Netherlands Antilles", nullptr}
# { "ALN", "TOLEMAC", "Alpha Jet, S.R.O.", "Slovakia", nullptr}
# { "ALN", "CHICAGO LINCOLN", "Air Lincoln", "United States", nullptr}
# { "ALO", "ALLEGHENY", "Allegheny Commuter Airlines", "United States", nullptr}
# { "ALP", "ALLPOINTS", "Allpoints Jet", "China", nullptr}
# { "ALP", "ALPINER", "Alpliner AG", "Switzerland", nullptr}
# { "ALQ", "ALTAIR", "Altair Aviation (1986)", "Canada", nullptr}
# { "ALR", "AEROLAIRE", "Lneas Areas Alaire S.L.", "Spain", nullptr}
# { "ALS", "AERALP", "Aeralp", "France", nullptr}
# { "ALT", "AERLINEAS CENTRALES", "Aerolneas Centrales", "Mexico", nullptr}
# { "ALU", "LUXORJET", "Air Luxor STP", "So Tom and Prncipe", nullptr}
# { "ALV", "AEROPOSTAL", "Aeropostal Alas de Venezuela", "Venezuela", nullptr}
# { "ALW", "ALNACIONAL", "Alas Nacionales, S.A.", "Dominican Republic", nullptr}
# { "ALX", "ALLCONGO", "Hewa Bora Airways", "Democratic Republic of the Congo", nullptr}
# { "ALY", "ALYESKA", "Alyeska Air Service", "United States", nullptr}
# { "ALZ", "", "Alta Flights (Charters) Ltd.", "Canada", nullptr}
# { "AMA", "ADIK", "ATMA", "Kazakhstan", nullptr}
# { "AMB", "CIVIL AIR AMBULANCE", "Deutsche Rettungsflugwacht", "Germany", nullptr}
# { "AMC", "AIR MALTA", "Air Malta", "Malta", &airline_logo_AMC}
# { "AMD", "AEROLINEAS MEDELLIN", "Aerolneas Medelln", "Colombia", nullptr}
# { "AME", "AIRMIL", "Spanish Air Force", "Spain", nullptr}
# { "AMF", "AMFLIGHT", "Ameriflight", "United States", &airline_logo_AMF}
# { "AMG", "AIR MINAS", "Air Minas Linhas Areas", "Brazil", nullptr}
# { "AMH", "MANN", "Alan Mann Helicopters Ltd.", "United Kingdom", nullptr}
# { "AMI", "AIR MALDIVES", "Air Maldives", "Maldives", nullptr}
# { "AMJ", "AVIATION AMOS", "Aviation Amos", "Canada", nullptr}
# { "AMK", "AMER AIR", "Amerer Air", "Austria", nullptr}
# { "AML", "MALAWI", "Air Malawi", "Malawi", nullptr}
# { "AMM", "AEROM", "Aeroputul International Marculesti", "Moldova", nullptr}
# { "AMM", "JETSET", "Air 2000", "United Kingdom", nullptr}
# { "AMN", "MONTENEGRO", "Air Montenegro", "Montenegro", nullptr}
# { "AMO", "AIR MONTREAL", "Air Montreal (Air Holdings Inc.)", "Canada", nullptr}
# { "AMP", "ATSA", "Aero Transporte S.A. (ATSA)", "Peru", nullptr}
# { "AMQ", "LIFELINE", "Aeromedicare Ltd.", "United Kingdom", nullptr}
# { "AMQ", "AMEX", "Aircraft Management and Consulting", "Poland", nullptr}
# { "AMR", "United States", "Air Specialties Corporation,AIR AM", "Air American", nullptr}
# { "AMS", "AIR MUSKOKA", "Air Muskoka", "Canada", nullptr}
# { "AMT", "AMTRAN", "ATA Airlines", "United States", &airline_logo_AMT}
# { "AMU", "AIR MACAO", "Air Macau", "Macao", &airline_logo_AMU}
# { "AMV", "", "AMC Airlines", "Egypt", nullptr}
# { "AMW", "AIR MIDWEST", "Air Midwest", "United States", nullptr}
# { "AMX", "AEROMEXICO", "Aeromxico", "Mexico", &airline_logo_AMX}
# { "AMY", "AIR AMBAR", "Air Ambar", "Dominican Republic", nullptr}
# { "AMZ", "AMIYA AIR", "Amiya Airline", "Nigeria", nullptr}
# { "ANA", "ALL NIPPON", "All Nippon Airways", "Japan", &airline_logo_ANA}
# { "ANB", "AIR NAV", "Air Navigation And Trading Co. Ltd.", "United Kingdom", nullptr}
# { "ANC", "United Kingdom", "Anglo Cargo,ANGLO", "Defunct", nullptr}
# { "AND", "AIR INDIANA", "National Jet Service", "United States", nullptr}
# { "AND", "SERVI ANDES", "Servicios Areos de los Andes", "Peru", nullptr}
# { "ANE", "AIR NOSTRUM", "Air Nostrum", "Spain", &airline_logo_ANE}
# { "ANG", "NIUGINI", "Air Niugini", "Papua New Guinea", nullptr}
# { "ANH", "ALAJNIHAH", "Alajnihah for Air Transport", "Libya", nullptr}
# { "ANI", "NIGALANTIC", "Air Atlantic (Nig) Limited", "Nigeria", nullptr}
# { "ANK", "Japan", "Air Nippon,ANK AIR", "merged intoAll Nippon Airways", nullptr}
# { "ANL", "AIR NACOIA", "Nacoia Lda", "Angola", nullptr}
# { "ANM", "NORAM", "Aerotransportacion de Norteamerica", "Mexico", nullptr}
# { "ANM", "ANTARES", "Antares Airtransport, Maintenance & Service GmbH", "Germany", nullptr}
# { "ANO", "TOPEND", "Airnorth", "Australia", nullptr}
# { "ANQ", "ANTIOQUIA", "Aerolnea de Antioquia", "Colombia", nullptr}
# { "ANS", "AEROANDES", "Andes Lneas Areas", "Argentina", nullptr}
# { "ANT", "AIR NORTH", "Air North Charter- Canada", "Canada", nullptr}
# { "ANV", "AIR NEVADA", "Air Nevada", "United States", nullptr}
# { "ANW", "AVINOR", "Aviacin Del Noroeste, S.A. de C.V.", "Mexico", nullptr}
# { "ANX", "SECRETARIA DEMARINA", "Secretaria de Marina", "Mexico", nullptr}
# { "ANZ", "NEW ZEALAND", "Air New Zealand", "New Zealand", &airline_logo_ANZ}
# { "AOA", "ALCON", "Alcon Servicios Areos, S.A. de C.V.", "Mexico", nullptr}
# { "AOB", "CARIBE CORO", "Aerocaribe Coro", "Venezuela", nullptr}
# { "AOC", "AERO AVCOM", "AVCOM", "Russia", nullptr}
# { "AOD", "AERO CZECH", "Aero Vodochody", "Czech Republic", nullptr}
# { "AOE", "", "Air One Executive", "Italy", nullptr}
# { "AOE", "LIVINGSTONE AIR", "Livingstone Executive", "Italy", nullptr}
# { "AOF", "ATAIR", "Atair Pty Ltd.", "South Africa", nullptr}
# { "AOG", "AVIP", "Aero VIP", "Argentina", nullptr}
# { "AOI", "ASTORIA", "Astoria, Inc.", "Canada", nullptr}
# { "AOJ", "ASTERIX", "Avcon Jet", "Austria", nullptr}
# { "AOK", "", "Aeroatlantico Colombia", "Colombia", nullptr}
# { "AOL", "ANGKOR AIR", "Angkor Airlines", "Cambodia", nullptr}
# { "AOM", "French Lines", "AOM French Airlines", "France", nullptr}
# { "AON", "AERO ENTERPRISE", "Aero Entreprise", "France", nullptr}
# { "AOO", "COMPANY AS", "As, Opened Joint Stock Company", "Ukraine", nullptr}
# { "AOP", "AEROPILOTO", "Aeropiloto", "Portugal", nullptr}
# { "AOR", "INTER-AFRO", "Afro International Ent. Limited", "Nigeria", nullptr}
# { "AOS", "AEROSOL", "Servicios Areos Del Sol, S.A. de C.V.", "Mexico", nullptr}
# { "AOT", "ASIA OVERNIGHT", "Asia Overnight Express", "Philippines", nullptr}
# { "AOU", "AIR TRACTOR", "Air Tractor", "Croatia", nullptr}
# { "AOV", "AEROVISION", "Aero Vision", "France", nullptr}
# { "AOX", "AEROVALLE", "Aerotaxi Del Valle", "Colombia", nullptr}
# { "APA", "CAN-AM", "Air Park Aviation Ltd.", "Canada", nullptr}
# { "APC", "AIRPAC", "Airpac Airlines, Inc.", "United States", nullptr}
# { "APD", "", "Sabre Pacific", "Australia", nullptr}
# { "APE", "AIR PARCEL", "Parcel Express", "United States", nullptr}
# { "APF", "AMAPOLA", "Amapola Flyg AB", "Sweden", nullptr}
# { "APG", "AIR PEOPLE", "Air People International", "Thailand", nullptr}
# { "APH", "AIRFLIGHT", "Alpha Aviation, Inc.", "United States", nullptr}
# { "API", "ASA PESADA", "ASA Pesada, Lda.", "Angola", nullptr}
# { "APJ", "AIR PEACH", "Peach Aviation", "Japan", nullptr}
# { "APL", "APPALACHIAN", "Appalachian Flying Service, Inc.", "United States", nullptr}
# { "APL", "AEREO PRINCIPAL", "Corporativo Aereo Principal", "Mexico", nullptr}
# { "APM", "ALASKA PACIFIC", "Airpac, Inc.", "United States", nullptr}
# { "APO", "AEROPRO", "Aeropro", "Canada", nullptr}
# { "APP", "AEROPERLAS", "Aerolneas Pacfico Atlntico, S.A. (Apair)", "Panama", nullptr}
# { "APQ", "ASPEN BASE", "Aspen Aviation", "United States", &airline_logo_APQ}
# { "APR", "AEROPERLAS", "Aerolneas Primordiales", "Mexico", nullptr}
# { "APT", "LAP", "LAP Colombia - Lneas Areas Petroleras, S.A.", "Colombia", nullptr}
# { "APU", "AEROPUMA", "Aeropuma, S.A.", "El Salvador", nullptr}
# { "APV", "AIR PLAN", "Air Plan International", "Democratic Republic of the Congo", nullptr}
# { "APW", "BIG A", "Arrow Air", "United States", nullptr}
# { "APX", "PARCEL EXPRESS", "Apex Air Cargo", "United States", nullptr}
# { "APY", "APA INTERNACIONAL", "APA Internacional", "Dominican Republic", nullptr}
# { "AQA", "ATCO", "Aeroatlas, S.A.", "Colombia", nullptr}
# { "AQL", "AQUILA", "Aquila Air Ltd.", "Canada", nullptr}
# { "AQN", "BUSHAIR", "Air Queensland", "Australia", nullptr}
# { "AQO", "ALCOA SHUTTLE", "Aluminum Company Of America", "United States", nullptr}
# { "AQT", "AVIOQUINTANA", "Aviones de Renta de Quintana Roo, S.A. de C.V.", "Mexico", nullptr}
# { "AQU", "QUARIUS", "AirQuarius Aviation", "South Africa", nullptr}
# { "AQZ", "QUANZA", "Aerodyne Charter Company", "United States", nullptr}
# { "ARA", "ARIK AIR", "Arik Air", "Nigeria", nullptr}
# { "ARB", "AVIAIR", "Avia Air N.V.", "Aruba", nullptr}
# { "ARC", "", "Air Routing International Corp.", "United States", nullptr}
# { "ARE", "LAN COLOMBIA", "LATAM Colombia", "Colombia", nullptr}
# { "ARF", "Aero Fox", "Aero Flight", "Germany", nullptr}
# { "ARG", "ARGENTINA", "Aerolneas Argentinas", "Argentina", &airline_logo_ARG}
# { "ARH", "AEROHELCA", "Aerohelicopteros", "Venezuela", nullptr}
# { "ARH", "ARROWHEAD", "Arrowhead Airways", "United States", nullptr}
# { "ARI", "AEROVICS", "Aero Vics", "Mexico", nullptr}
# { "ARJ", "", "Aerojet de Costa Rica, S.A.", "Costa Rica", nullptr}
# { "ARK", "LINK SERVICE", "Aero Link Air Services S.L.", "Spain", nullptr}
# { "ARL", "AIRLEC", "Airlec - Air Aquitaine Transport", "France", nullptr}
# { "ARM", "AMEX", "Aeromarket Express", "Spain", nullptr}
# { "ARO", "ARROW", "Arrow Aviation Ltd.", "Canada", nullptr}
# { "ARO", "ACERO", "Acero Taxi", "Mexico", nullptr}
# { "ARP", "IVORYCORP", "Aero Corporate", "Cte d'Ivoire", nullptr}
# { "ARQ", "ARMSTRONG", "Armstrong Air, Inc.", "Canada", nullptr}
# { "ARR", "AIR ARMENIA", "Air Armenia", "Armenia", nullptr}
# { "ARS", "METSERVICE", "Aeromet Servicios", "Chile", nullptr}
# { "ART", "AEROTAL", "Aerotal Aerolneas Territoriales de Colombia Ltda.", "Colombia", nullptr}
# { "ART", "SMART LYNX", "Smartlynx Airlines", "Latvia", nullptr}
# { "ARU", "ARUBA", "Aruba Airlines", "Aruba", &airline_logo_ARU}
# { "ARV", "ARAVCO", "Aravco Ltd.", "United Kingdom", nullptr}
# { "ARW", "ARIABIRD", "Aria", "France", nullptr}
# { "ARX", "AIREX", "Air Xpress, Inc.", "United States", nullptr}
# { "ARY", "GOSEY", "Argosy Airways", "United States", nullptr}
# { "ARZ", "AIR RESORTS", "Air Resorts", "United States", nullptr}
# { "ASA", "ALASKA", "Alaska Airlines, Inc.", "United States", &airline_logo_ASA}
# { "ASB", "AIR SPRAY", "Air-Spray 1967 Ltd.", "Canada", nullptr}
# { "ASC", "AIR STAR", "Air Star Corporation", "Canada", nullptr}
# { "ASD", "", "Air Sinai", "Egypt", nullptr}
# { "ASD", "AIR SINAI", "Air Sinai", "Egypt", nullptr}
# { "ASE", "MOROZOV", "Airstars", "Russia", nullptr}
# { "ASF", "AUSTRIAN AIRFORCE", "Austrian Air Force", "Austria", nullptr}
# { "ASF", "SCHEFF", "Air Schefferville, Inc.", "Canada", nullptr}
# { "ASG", "AFRICAN STAR", "African Star Airways (PTY) Ltd.", "South Africa", nullptr}
# { "ASH", "AIR SHUTTLE", "Mesa Airlines", "United States", &airline_logo_ASH}
# { "ASI", "AEROSUN", "Aerosun International, Inc.", "United States", nullptr}
# { "ASJ", "SATELLITE", "Air Satellite", "Canada", nullptr}
# { "ASK", "MULTISKY", "Aerosky", "Spain", nullptr}
# { "ASK", "AIR SASK", "La Ronge Aviation Services", "Canada", nullptr}
# { "ASL", "AIR SERBIA", "Air Serbia", "Serbia", &airline_logo_ASL}
# { "ASM", "AWESOME", "Awesome Flight Services (PTY) Ltd.", "South Africa", nullptr}
# { "ASN", "", "Air and Sea Transport", "Russia", nullptr}
# { "ASO", "AERO NITRA", "Aero Slovakia", "Slovakia", nullptr}
# { "ASP", "AIRSPRINT", "Airsprint", "Canada", nullptr}
# { "ASQ", "ACEY", "Atlantic Southeast Airlines", "United States", &airline_logo_ASQ}
# { "ASQ", "ACEY", "ExpressJet", "United States", &airline_logo_ASQ}
# { "ASR", "SOTRAVIA", "Aero Sotravia", "France", nullptr}
# { "ASR", "ALL STAR", "All Star Airlines, Inc.", "United States", nullptr}
# { "ASS", "AIR CLASS", "Air Class, S.A. de C.V.", "Mexico", nullptr}
# { "AST", "AEROESTE", "Aerolneas Del Oeste", "Mexico", nullptr}
# { "ASV", "AIR SEOUL", "Air Seoul", "South Korea", nullptr}
# { "ASV", "ASTRAVIA", "Astravia-Bissau Air Transports Ltd.", "Guinea-Bissau", nullptr}
# { "ASW", "AIRSOUTHWEST", "Air Southwest Ltd.", "Canada", nullptr}
# { "ASX", "AIRSPEC", "Air Special", "Czech Republic", nullptr}
# { "ASY", "AUSSIE", "Royal Australian Air Force", "Australia", nullptr}
# { "ASZ", "AIR ASTRAKHAN", "Astrakhan Airlines", "Russia", nullptr}
# { "ATA", "", "Air Transport Association", "United States", nullptr}
# { "ATB", "STARLITE", "Atlantair Ltd.", "Canada", nullptr}
# { "ATC", "TANZANIA", "Air Tanzania", "Tanzania", &airline_logo_ATC}
# { "ATC", "TANZANIA", "Air Tanzania Company Limited", "Tanzania", &airline_logo_ATC}
# { "ATD", "AEROTOURS", "Aerotours Dominicana", "Dominican Republic", nullptr}
# { "ATE", "ATLANTIS CANADA", "Atlantis Transportation Services, Ltd.", "Canada", nullptr}
# { "ATF", "AEROTECNICAS", "Compaa Aerotcnicas Fotogrficas", "Spain", nullptr}
# { "ATG", "MOLDCARGO", "Aerotranscargo", "Moldova", &airline_logo_ATG}
# { "ATH", "AIR TRAVEL", "Air Travel Corp.", "United States", nullptr}
# { "ATI", "", "Aero-Tropics Air Services", "Australia", nullptr}
# { "ATJ", "SNOOPY", "Air Traffic GmbH", "Germany", nullptr}
# { "ATK", "Colombia", "AeroTACA,AEROTACA", "defunct", nullptr}
# { "ATM", "AIRTAS", "Airlines of Tasmania", "Australia", nullptr}
# { "ATN", "AIR TRANSPORT", "Air Transport International", "United States", &airline_logo_ATN}
# { "ATP", "ASTRAL", "ASTRAL Colombia - Aerotransportes Especiales Ltda.", "Colombia", nullptr}
# { "ATQ", "MULTI", "Air Transport Schiphol", "Netherlands", nullptr}
# { "ATQ", "COLIBRI", "CHC Helicopters Nigeria", "Nigeria", nullptr}
# { "ATR", "ATLAS-AIR", "Atlas Airlines", "United States", nullptr}
# { "ATS", "", "Air Transport Service", "Democratic Republic of the Congo", nullptr}
# { "ATT", "ATTAWASOL AIR", "Attawasol Airlines", "Libya", nullptr}
# { "ATT", "AERTURAS", "Aer Turas", "Ireland", nullptr}
# { "ATU", "ATLANT HUNGARY", "Atlant Aerobatics Ltd.", "Hungary", nullptr}
# { "ATV", "AVANTI AIR", "Avanti Air", "Germany", nullptr}
# { "ATW", "DEVIL", "Air Antwerp", "Belgium", nullptr}
# { "ATW", "Canada", "Aero Trades (Western) Ltd.,AERO TRADES", "defunct", nullptr}
# { "ATX", "AIRTAX", "Warwickshire Aerocentre Ltd.", "United Kingdom", nullptr}
# { "ATZ", "ACE TAXI", "Ace Air", "South Korea", nullptr}
# { "AUA", "AUSTRIAN", "Austrian Airlines", "Austria", &airline_logo_AUA}
# { "AUB", "AUGSBURG-AIR", "Augsburg Airways", "Germany", nullptr}
# { "AUC", "AUSCARGO", "Transaustralian Air Express", "Australia", nullptr}
# { "AUD", "AUDI AIR", "Audi Air, Inc.", "United States", nullptr}
# { "AUF", "AUGUSTA", "Augusta Air Luftfahrtunternehmen", "Germany", nullptr}
# { "AUH", "SULTAN", "Abu Dhabi Amiri Flight", "United Arab Emirates", nullptr}
# { "AUI", "UKRAINE INTERNATIONAL", "Ukraine International Airlines", "Ukraine", nullptr}
# { "AUJ", "AUSTROJET", "Business Flight Salzburg", "Austria", nullptr}
# { "AUL", "ARCHANGELSK AIR", "Nordavia", "Russia", nullptr}
# { "AUM", "ATLAMUR", "Air Atlantic Uruguay", "Uruguay", nullptr}
# { "AUN", "AVIONES UNIDOS", "Aviones Unidos", "Mexico", nullptr}
# { "AUN", "COMMON SKY", "Common Sky", "Austria", nullptr}
# { "AUO", "UNIFORM OSCAR", "Empresa (Aero Uruguay), S.A.", "Uruguay", nullptr}
# { "AUP", "", "Avia Business Group", "Russia", nullptr}
# { "AUR", "AYLINE", "Aurigny Air Services", "United Kingdom", nullptr}
# { "AUS", "", "Aus-Air", "Australia", nullptr}
# { "AUT", "AUSTRAL", "Austral Lneas Areas", "Argentina", nullptr}
# { "AUU", "AURORA AIR", "Aurora Aviation, Inc.", "United States", nullptr}
# { "AUX", "", "Air Uganda International Ltd.", "Uganda", nullptr}
# { "AUY", "AUSA", "Aerolneas Uruguayas, S.A.", "Uruguay", nullptr}
# { "AUZ", "AUSTRALIAN", "Australian Airlines", "Australia", nullptr}
# { "AVA", "AVIANCA", "Avianca", "Colombia", &airline_logo_AVA}
# { "AVB", "BEAUPAIR", "Aviation Beauport", "United Kingdom", nullptr}
# { "AVD", "ALAMO", "lamo Aviacin, S.L.", "Spain", nullptr}
# { "AVE", "AVENSA", "Avensa", "Venezuela", nullptr}
# { "AVF", "CARIBOO", "Aviair Aviation Ltd.", "Canada", nullptr}
# { "AVG", "AVILEF", "Aviation Legacy", "Gambia", nullptr}
# { "AVG", "DJIBOUTI FALCON", "Air Falcon", "Djibouti", nullptr}
# { "AVH", "KENT HELI", "AV8 Helicopters", "United Kingdom", nullptr}
# { "AVJ", "ATOMIC", "Avia Traffic Company", "Kyrgyzstan", nullptr}
# { "AVK", "AVIATE-COPTER", "AV8 Helicopters", "South Africa", nullptr}
# { "AVM", "AVEMEX", "Aviacin Ejecutiva Mexicana, S.A.", "Mexico", nullptr}
# { "AVN", "AIR VAN", "Air Vanuatu", "Vanuatu", nullptr}
# { "AVO", "AVIATION WORK", "Aviation at Work", "South Africa", nullptr}
# { "AVP", "AVCORP", "Avcorp Registrations", "United Kingdom", nullptr}
# { "AVP", "AVIA PUEBLA", "Aviacion Corporativa de Peubla", "Mexico", nullptr}
# { "AVQ", "AQUILINE", "Aviation Services, Inc.", "United States", nullptr}
# { "AVR", "ACTIVE AERO", "Active Aero Charter, Inc.", "United States", nullptr}
# { "AVS", "AVIALSA", "Avialsa T-35", "Spain", nullptr}
# { "AVT", "ASIAVIA", "Asia Avia Airlines", "Indonesia", nullptr}
# { "AVU", "AVIASUD", "Avia Sud Arotaxi", "France", nullptr}
# { "AVV", "AIRVANTAGE", "Airvantage Incorporated", "United States", nullptr}
# { "AVW", "AVIATOR", "Aviator Airways", "Greece", nullptr}
# { "AVX", "PASLAUGA", "Aviapaslauga", "Lithuania", nullptr}
# { "AVX", "", "Aeroclub de Vitoria", "Spain", nullptr}
# { "AVY", "AEROVARADERO", "Aerovaradero, S.A.", "Cuba", nullptr}
# { "AVZ", "AIR VALENCIA", "Air Valencia", "Spain", nullptr}
# { "AWB", "AIRNAT", "Airways International, Inc.", "United States", nullptr}
# { "AWC", "ZAP", "Titan Airways", "United Kingdom", nullptr}
# { "AWD", "", "Providence Aviation Services", "Pakistan", nullptr}
# { "AWE", "CACTUS", "America West Airlines", "United States", &airline_logo_AWE}
# { "AWE", "United States", "US Airways,CACTUS", "defunct", &airline_logo_AWE}
# { "AWF", "", "Aeroforward", "United States", nullptr}
# { "AWG", "ANIMA WINGS", "Animawings", "Romania", nullptr}
# { "AWI", "WISCONSIN", "Air Wisconsin", "United States", &airline_logo_AWI}
# { "AWJ", "SAHEL AIRLINES", "Sahel Airlines", "Niger", nullptr}
# { "AWK", "AIRWORK", "Airwork", "New Zealand", nullptr}
# { "AWL", "", "Air Walser", "Malta", nullptr}
# { "AWL", "AUSSIEWORLD", "Australian Wetleasing", "Australia", nullptr}
# { "AWN", "AIR NIAMEY", "Air Niamey", "Niger", nullptr}
# { "AWO", "AWOOD AIR", "Awood Air Ltd.", "Canada", nullptr}
# { "AWP", "", "Aeroworld Pakistan", "Pakistan", nullptr}
# { "AWQ", "WAGON AIR", "Indonesia AirAsia", "Indonesia", nullptr}
# { "AWR", "ARCTIC WINGS", "Arctic Wings And Rotors Ltd.", "Canada", nullptr}
# { "AWS", "ARAB WINGS", "Arab Wings", "Jordan", nullptr}
# { "AWT", "AIR WEST", "Air West", "Canada", nullptr}
# { "AWT", "ALBAWINGS", "Albawings", "Albania", nullptr}
# { "AWU", "SYLT-AIR", "Sylt Air GmbH", "Germany", nullptr}
# { "AWV", "AIRWAVE", "Airwave Transport, Inc.", "Canada", nullptr}
# { "AWW", "United Kingdom", "Air Wales,RED DRAGON", "defunct", nullptr}
# { "AWX", "ALLWEATHER", "Civil Aviation AuthorityDirectorate of Airspace Policy", "United Kingdom", nullptr}
# { "AWY", "AEROWEE", "Aeroway, S.L.", "Spain", nullptr}
# { "AWZ", "", "AirWest", "Sudan", nullptr}
# { "AXB", "EXPRESS INDIA", "Air India Express", "India", nullptr}
# { "AXD", "AIR SUDEX", "Air Express", "Sudan", nullptr}
# { "AXF", "FREIGHTEXPRESS", "Asian Express Airlines", "Australia", nullptr}
# { "AXH", "AEROMEXHAGA", "Aeromexhaga", "Mexico", nullptr}
# { "AXI", "AIR FREIGHTER", "Aeron International Airlines, Inc.", "United States", nullptr}
# { "AXK", "EXPRESS JET", "African Express Airways", "Kenya", nullptr}
# { "AXL", "EXEL COMMUTER", "Air Exel", "Netherlands", nullptr}
# { "AXM", "RED CAP", "AirAsia", "Malaysia", nullptr}
# { "AXN", "ALEXANDROS", "Alexandair", "Greece", nullptr}
# { "AXP", "AEROMAX SPAIN", "Aeromax", "Spain", nullptr}
# { "AXQ", "ACTION AIR", "Action Airlines (Action Air Charter)", "United States", nullptr}
# { "AXR", "RENTAXEL", "Axel Rent, S.A.", "Mexico", nullptr}
# { "AXS", "ALTUS", "Altus Airlines", "United States", nullptr}
# { "AXV", "AXAVIA", "Aviaxess", "France", nullptr}
# { "AXX", "IMPEX", "Avioimpex A.D.p.o.", "Macedonia", nullptr}
# { "AXX", "SKY SHUTTLE", "Advance Air Luftfahrtgesellschaft", "Germany", nullptr}
# { "AXY", "LEGEND", "Air X Charter", "Malta", &airline_logo_AXY}
# { "AXY", "AXIS", "Axis Airways", "France", &airline_logo_AXY}
# { "AYB", "BELGIAN ARMY", "Belgian Army", "Belgium", nullptr}
# { "AYD", "AIRLINES ALADIA", "Aladia Airlines", "Mexico", nullptr}
# { "AYE", "AIR YING AN", "Yunnan Yingan Airlines", "China", nullptr}
# { "AYG", "AIR YANGON", "Yangon Airways", "Burma", nullptr}
# { "AYK", "", "Aykavia Aircompany", "Armenia", nullptr}
# { "AYM", "AIRMAN", "Airman, S.L.", "Spain", nullptr}
# { "AYN", "ATLANTIC NICARAGUA", "Atlantic Airlines, S.A.", "Nicaragua", nullptr}
# { "AYR", "CYGNET", "Flight Training Europe", "Spain", nullptr}
# { "AYS", "", "Awsaj Aviation Services", "Libya", nullptr}
# { "AYT", "AYEET", "Ayeet Aviation & Tourism", "Israel", nullptr}
# { "AYU", "", "Yuhi Air Lines", "Japan", nullptr}
# { "AYZ", "ATLANT-SOYUZ", "Atlant-Soyuz Airlines", "Russia", nullptr}
# { "AZA", "ALITALIA", "Alitalia", "Italy", &airline_logo_AZA}
# { "AZB", "TUMARA", "Azamat", "Kazakhstan", nullptr}
# { "AZB", "ZAAB AIR", "Zaab Air", "Ghana", nullptr}
# { "AZE", "ARCUS AIR", "Arcus-Air Logistic", "Germany", nullptr}
# { "AZF", "AIR ZERMATT", "Air Zermatt AG", "Switzerland", nullptr}
# { "AZG", "SILK WEST", "Silk Way West Airlines", "Azerbaijan", &airline_logo_AZG}
# { "AZG", "SAKSERVICE", "Sakaviaservice", "Georgia", &airline_logo_AZG}
# { "AZI", "ASTRA", "Astra Airlines", "Greece", nullptr}
# { "AZI", "AZZURRA", "Azzurra Air", "Italy", nullptr}
# { "AZJ", "", "Zas Air", "Egypt", nullptr}
# { "AZK", "AZALHELICOPTER", "Azalhelikopter", "Azerbaijan", nullptr}
# { "AZL", "SKY AFRICA", "Africa One", "Zambia", nullptr}
# { "AZM", "AEROCOZUMEL", "Aerocozumel", "Mexico", nullptr}
# { "AZN", "", "Lnea Area Amaszonas", "Bolivia", nullptr}
# { "AZP", "ARIZONA PACIFIC", "Arizona Pacific Airways", "United States", nullptr}
# { "AZP", "GUARANI", "Amaszonas Paraguay", "Paraguay", nullptr}
# { "AZQ", "SILK LINE", "Silk Way Airlines", "Azerbaijan", nullptr}
# { "AZR", "ZENAIR", "Zenith Air", "South Africa", nullptr}
# { "AZS", "ZITOTRANS", "Aviacon Zitotrans Air Company", "Russia", nullptr}
# { "AZT", "AZIMUT", "Azimut, S.A.", "Spain", nullptr}
# { "AZU", "Azul", "Azul Linhas Areas Brasileiras", "Brazil", &airline_logo_AZU}
# { "AZW", "AIR ZIMBABWE", "Air Zimbabwe", "Zimbabwe", nullptr}
# { "AZX", "AZIMA", "Air Max Africa", "Gabon", nullptr}
# { "AZY", "AZTEC WORLD", "Aztec Worldwide Airlines", "United States", nullptr}
# { "AZY", "ARIZAIR", "Arizona Airways, Inc.", "United States", nullptr}
# { "AZZ", "AZZA TRANSPORT", "Azza Transport", "Sudan", nullptr}
# { "BAA", "BALKAN AGRO", "Balkan Agro Aviation", "Bulgaria", nullptr}
# { "BAB", "AWAL", "Bahrain Air BSC (Closed)", "Bahrain", nullptr}
# { "BAC", "", "BAC Leasing Limited", "United Kingdom", nullptr}
# { "BAE", "FELIX", "BAE Systems", "United Kingdom", nullptr}
# { "BAF", "BELGIAN AIRFORCE", "Belgian Air Force", "Belgium", nullptr}
# { "BAG", "SPEEDWAY", "Dba", "Germany", nullptr}
# { "BAH", "BAHRAIN", "The Amiri Flight", "Bahrain", nullptr}
# { "BAJ", "RODEO", "Baker Aviation", "United States", nullptr}
# { "BAK", "BLACKHAWK", "Blackhawk Airways", "United States", nullptr}
# { "BAL", "BELLEAIR EUROPE", "Belle Air Europe", "Italy", nullptr}
# { "BAL", "BRITANNIA", "Britannia Airways", "United Kingdom", nullptr}
# { "BAM", "BUSINESS AIR", "Business Air Services", "Canada", nullptr}
# { "BAN", "PENGUIN", "British Antarctic Survey", "United Kingdom", nullptr}
# { "BAP", "BIG APPLE", "Trans International Express Aviation", "United States", nullptr}
# { "BAR", "BRADLEY", "Bradly Air (Charter) Services", "Canada", nullptr}
# { "BAS", "AEROSERV", "Aero Services", "Barbados", nullptr}
# { "BAT", "BALLISTIC", "Premiair", "Luxembourg", nullptr}
# { "BAU", "AIR BISSAU", "Bissau Airlines", "Guinea-Bissau", nullptr}
# { "BAV", "BAY AIR", "Bay Aviation Ltd", "Bangladesh", &airline_logo_BAV}
# { "BAW", "SPEEDBIRD", "British Airways", "United Kingdom", &airline_logo_BAW}
# { "BAX", "", "Best Aero Handling Ltd", "Russia", nullptr}
# { "BAY", "", "Bravo Airways", "Ukraine", nullptr}
# { "BBA", "BANAIR", "Bannert Air", "Austria", nullptr}
# { "BBB", "BLACKBIRD", "SwedJet Airways", "Sweden", nullptr}
# { "BBC", "BANGLADESH", "Biman Bangladesh Airlines", "Bangladesh", nullptr}
# { "BBD", "BLUE CARGO", "Bluebird Nordic", "Iceland", nullptr}
# { "BBE", "BABEL AIR", "Ababeel Aviation", "Sudan", nullptr}
# { "BBF", "SPEEDCHARTER", "B-Air Charter", "Germany", nullptr}
# { "BBJ", "BLUE KOREA", "Blue Air Lines", "South Korea", nullptr}
# { "BBL", "BLUE", "IBMEuroflight Operations", "Switzerland", nullptr}
# { "BBN", "BRABAZON", "Civil Aviation AuthorityAirworthiness Division", "United Kingdom", nullptr}
# { "BBO", "BABOO", "Flybaboo", "Switzerland", nullptr}
# { "BBR", "SANTA BARBARA", "Santa Barbara Airlines", "Venezuela", nullptr}
# { "BBS", "BEIBARS", "Beibars CJSC", "Kazakhstan", nullptr}
# { "BBT", "AGYDAL", "Air Bashkortostan", "Russia", nullptr}
# { "BBV", "BRAVO EUROPE", "Bravo Airlines", "Spain", nullptr}
# { "BBW", "BEEBEE AIRWAYS", "BB Airways", "Nepal", nullptr}
# { "BBZ", "COBRA", "Bluebird Aviation", "Kenya", nullptr}
# { "BCB", "WAVEBIRD", "Carib Express", "Barbados", nullptr}
# { "BCF", "BACH", "BACH Flugbetriebsges", "Austria", nullptr}
# { "BCH", "BEACHBALL", "Phillips Air", "United States", nullptr}
# { "BCI", "BLUE ISLAND", "Blue Islands", "United Kingdom", nullptr}
# { "BCJ", "BLUE BOY", "Blue Jet Charters", "Poland", nullptr}
# { "BCK", "BANKCHECK", "Priority Aviation Company", "United States", nullptr}
# { "BCL", "", "British Caribbean Airways", "United Kingdom", nullptr}
# { "BCN", "BLUE OCEAN", "Ocean Air", "Mauritania", nullptr}
# { "BCR", "BACKER", "British Charter", "United Kingdom", nullptr}
# { "BCS", "EUROTRANS", "European Air Transport", "Belgium", nullptr}
# { "BCT", "BOBCAT", "BCT Aviation", "United Kingdom", nullptr}
# { "BCV", "BUSINESS AVIATION", "Business Aviation Center", "Ukraine", nullptr}
# { "BCY", "CITY JET", "CityJet", "Ireland", nullptr}
# { "BCY", "CITY-IRELAND", "CityJet", "Ireland", nullptr}
# { "BDA", "BLUE DART", "Blue Dart Aviation", "India", &airline_logo_BDA}
# { "BDF", "BISSAU DISCOVERY", "Bissau Discovery Flying Club", "Guinea-Bissau", nullptr}
# { "BDG", "BULLDOG", "Mississippi State University", "United States", nullptr}
# { "BDM", "BANDAMA", "Air Bandama", "Ivory Coast", nullptr}
# { "BDN", "GAUNTLET", "DERA Boscombe Down", "United Kingdom", nullptr}
# { "BDR", "BADR AIR", "Badr Airlines", "Sudan", nullptr}
# { "BDS", "SOUTH ASIAN", "South Asian Airlines", "Bangladesh", nullptr}
# { "BDV", "ABERDAV", "Aberdair Aviation", "Kenya", nullptr}
# { "BEA", "BEST AIR", "Best Aviation Ltd", "Bangladesh", nullptr}
# { "BEC", "", "State Air Company Berkut", "Kazakhstan", nullptr}
# { "BED", "BELOGORYE", "Belgorod Aviation Enterprise", "Russia", nullptr}
# { "BEE", "JERSEY", "Flybe", "United Kingdom", &airline_logo_BEE}
# { "BEF", "BALEAR EXPRESS", "Balear Express", "Spain", nullptr}
# { "BEH", "BLUECOPTER", "Bel Air Helicopters", "Denmark", nullptr}
# { "BEK", "BERKUT", "Berkut Air", "Kazakhstan", nullptr}
# { "BEL", "BEE-LINE", "Brussels Airlines", "Belgium", &airline_logo_BEL}
# { "BER", "AIR BERLIN", "Air Berlin", "Germany", &airline_logo_BER}
# { "BES", "BIRD EXPRESS", "Aero Services Executive", "France", nullptr}
# { "BET", "BETA CARGO", "BETA - Brazilian Express Transportes Areos", "Brazil", nullptr}
# { "BEZ", "SEA BREEZE", "Kingfisher Air Services", "United States", nullptr}
# { "BFA", "", "Presidence Du Faso", "Burkina Faso", nullptr}
# { "BFC", "BASLER", "Basler Flight Service", "United States", nullptr}
# { "BFF", "AIR BAFFIN", "Air Baffin", "Canada", nullptr}
# { "BFG", "BEARFLIGHT", "Bear Flight", "Sweden", nullptr}
# ...
# { "WAF", "FLAMENCO", "Flamenco Airways", "United States", nullptr}
# { "WAG", "", "Wisconsin Air National Guard", "United States", nullptr}
# { "WAJ", "WING ASIA", "AirAsia Japan", "Japan", nullptr}
# { "WAL", "WESTERN", "Western Airlines", "United States", nullptr}
# { "WAL", "WESTERN ARCTIC", "Western Arctic Air", "Canada", nullptr}
# { "WAM", "TAXI CARGO", "Air Taxi & Cargo", "Sudan", nullptr}
# { "WAN", "WATANIYA", "Wataniya Airways", "Kuwait", nullptr}
# { "WAP", "ARROW PANAMA", "Arrow Panama", "Panama", nullptr}
# { "WAR", "WARBIRDS", "NZ Warbirds Association", "New Zealand", nullptr}
# { "WAS", "", "Air-Watania", "Iraq", nullptr}
# { "WAS", "WALSTEN", "Walsten Air Services", "Canada", nullptr}
# { "WAT", "", "Wings Air Transport", "Sudan", nullptr}
# { "WAV", "WARBELOW", "Warbelow's Air Ventures", "United States", nullptr}
# { "WAW", "WING SHUTTLE", "Wings Airways", "United States", nullptr}
# { "WAY", "GARONNE", "Airways", "France", nullptr}
# { "WBA", "WESTBIRD", "Finncomm Airlines", "Finland", nullptr}
# { "WBR", "WEBER", "Multi-Aero", "United States", nullptr}
# { "WCA", "WEST-LEONE", "West Coast Airways", "Sierra Leone", nullptr}
# { "WCB", "KILO YANKEE", "West Africa Airlines", "Ghana", nullptr}
# { "WCC", "WEST COAST", "Sport Air Travel", "United States", nullptr}
# { "WCC", "WEST COAST", "West Coast Charters", "United States", nullptr}
# { "WCG", "WHISKY INDIA", "West Coast Airlines", "Ghana", nullptr}
# { "WCO", "COLUMBIA HELI", "Columbia Helicopters", "United States", nullptr}
# { "WCP", "WHITECAP", "Primaris Airlines", "United States", nullptr}
# { "WCR", "WEST CARIBBEAN", "West Caribbean Costa Rica", "Costa Rica", nullptr}
# { "WCW", "WEST", "West Caribbean Airways", "Colombia", nullptr}
# { "WCY", "TITAN AIR", "Viking Express", "United States", nullptr}
# { "WDA", "WIMBI DIRA", "Wimbi Dira Airways", "Democratic Republic of Congo", nullptr}
# { "WDG", "WATCHDOG", "Ministry of Agriculture, Fisheries and Food", "United Kingdom", nullptr}
# { "WDK", "WOODSTOCK", "Oxford Air Services", "United Kingdom", nullptr}
# { "WDL", "WDL", "WDL Aviation", "Germany", nullptr}
# { "WDR", "WIND RIDER", "Air Net Private Charter", "United States", nullptr}
# { "WDS", "WINDS", "Four Winds Aviation", "United States", nullptr}
# { "WDY", "WINDY CITY", "Chicago Jet Group", "United States", nullptr}
# { "WDY", "WINDYCITY", "Phoenix Airline Services", "United States", nullptr}
# { "WEA", "WHITE EAGLE", "White Eagle Aviation", "Poland", nullptr}
# { "WEB", "WEB-BRASIL", "WebJet Linhas Areas", "Brazil", nullptr}
# { "WEC", "AIRGO", "Universal Airlines", "United States", nullptr}
# { "WEL", "VELES", "Veles, Ukrainian Aviation Company", "Ukraine", nullptr}
# { "WEN", "ENCORE", "WestJet Encore", "Canada", nullptr}
# { "WES", "WEST INDIAN", "Rainbow International Airlines", "United States", nullptr}
# { "WES", "WEST EX", "Western Express Air Lines", "Canada", nullptr}
# { "WEV", "VICTORIA UGANDA", "Victoria International Airways", "Uganda", nullptr}
# { "WEW", "WESTWIND", "West Wind Aviation", "Canada", nullptr}
# { "WEX", "WINGS EXPRESS", "Wings Express", "United States", nullptr}
# { "WFC", "SWIFTCOPTERS", "Swift Copters", "Switzerland", nullptr}
# { "WFD", "AVRO", "BAE Systems", "United Kingdom", nullptr}
# { "WFO", "WILBURS", "Wilbur's Flight Operations", "United States", nullptr}
# { "WFT", "WORLD FLIGHT", "Aircharters Worldwide", "United States", nullptr}
# { "WGA", "WEGA FRANKO", "Vega Air Company", "Ukraine", nullptr}
# { "WGN", "WESTERN GLOBAL", "Western Global Airlines", "United States", nullptr}
# { "WGP", "GRAND PRIX", "Williams Grand Prix Engineering", "United Kingdom", nullptr}
# { "WGS", "AIRWINGS", "Airwings oy", "Finland", nullptr}
# { "WGT", "WORLDGATE", "Volkswagen AirService GmbH", "United Kingdom", nullptr}
# { "WHE", "WESTLAND", "Westland Helicopters", "United Kingdom", nullptr}
# { "WHH", "", "Richy Skylark", "Sri Lanka", nullptr}
# { "WHR", "WHIRLEYBIRD", "Hummingbird Helicopter Service", "United States", nullptr}
# { "WHS", "WEEKING", "Wiking Helikopter Service", "Germany", nullptr}
# { "WHT", "WHITEJET", "White", "Portugal", nullptr}
# { "WHY", "AIR SOREL", "Air Sorel", "Canada", nullptr}
# { "WIA", "WINDWARD", "Windward Islands Airways International", "Netherlands", nullptr}
# { "WIF", "WIDEROE", "Widere", "Norway", nullptr}
# { "WIG", "WIGGINS AIRWAYS", "Wiggins Airways", "United States", nullptr}
# { "WIL", "WILLIAMETTE", "Aero Air", "United States", nullptr}
# { "WIN", "WINLINK", "Winlink", "Saint Lucia", nullptr}
# { "WIS", "WISCAIR", "Paccair", "United States", nullptr}
# { "WIT", "STRIKER", "RAF Wittering", "United Kingdom", nullptr}
# { "WIW", "VEE-AVIA", "V-avia Airline", "Ukraine", nullptr}
# { "WIZ", "WIZARD", "Micromatter Technology Solutions", "United Kingdom", nullptr}
# { "WJA", "WESTJET", "WestJet", "Canada", &airline_logo_WJA}
# { "WKH", "WEST-KHARKOV", "Kharkov Aircraft Manufacturing Company", "Ukraine", nullptr}
# { "WLA", "AIRLIMITED", "Airwaves Airlink", "Zambia", nullptr}
# { "WLB", "WING LEBANON", "Wings of Lebanon Aviation", "Lebanon", nullptr}
# { "WLC", "WELCOMEAIR", "Welcome Air", "Austria", nullptr}
# { "WLG", "GOUMRAK", "Air Volga", "Russia", nullptr}
# { "WLK", "SKYWATCH", "Skyrover CC", "South Africa", nullptr}
# { "WLR", "AIRWALSER", "Air Walser", "Italy", nullptr}
# { "WLS", "WALES", "Air Wales Virtual", "United Kingdom", nullptr}
# { "WLT", "WINGLET", "Aviation Partners", "United States", nullptr}
# { "WLV", "WOLVERINE", "Aviation North", "United States", nullptr}
# { "WLX", "WEST LUX", "West Air Luxembourg", "Luxembourg", nullptr}
# { "WML", "MARLIN", "Chantilly Air", "United States", nullptr}
# { "WNA", "WINAIR", "Winair", "United States", nullptr}
# { "WNR", "WONDAIR", "Wondair on Demand Aviation", "Spain", nullptr}
# { "WOA", "WORLD", "World Airways", "United States", nullptr}
# { "WOK", "WOKAIR", "Kovar Air", "Czech Republic", nullptr}
# { "WOL", "WINGJET", "Wings Aviation", "Guyana", nullptr}
# { "WON", "WINGS ABADI", "Wings Air", "Indonesia", nullptr}
# { "WOW", "SWALLOW", "Air Southwest", "United Kingdom", &airline_logo_WOW}
# { "WOW", "WOW air", "WOW air", "Iceland", &airline_logo_WOW}
# { "WPA", "WESTPAC", "Western Pacific Airservice", "Solomon Islands", nullptr}
# { "WPK", "WOLFPACK", "Air-Lift Associates", "United States", nullptr}
# { "WPR", "WESTPAC RESCUE", "Auckland Regional Rescue Helicopter Trust", "New Zealand", nullptr}
# { "WPT", "WAPITI", "Wapiti Aviation", "Canada", nullptr}
# { "WRA", "", "White River Air Services", "Canada", nullptr}
# { "WRF", "WRIGHT FLYER", "Wright Air Service", "United States", nullptr}
# { "WRR", "WRAP AIR", "WRA Inc", "United States", nullptr}
# { "WRT", "WRIGHT-AIR", "Wright Airlines", "United States", nullptr}
# { "WSA", "WESTATES", "Westgates Airlines", "United States", nullptr}
# { "WSC", "WESTCAR", "Westair Cargo Airlines", "Cte d'Ivoire", nullptr}
# { "WSF", "", "West African Airlines", "Benin", nullptr}
# { "WSG", "WASAYA", "Wasaya Airways", "Canada", nullptr}
# { "WSI", "WIND SPIRIT", "Wind Spirit Air", "United States", nullptr}
# { "WSL", "WEST LINE", "Westflight Aviation", "United Kingdom", nullptr}
# { "WSM", "WISMAN", "Wisman Aviation", "United States", nullptr}
# { "WSN", "WINGSPAN", "Advanced Air", "United States", nullptr}
# { "WST", "WESTERN BAHAMAS", "Western Air", "Bahamas", nullptr}
# { "WSW", "SWOOP", "Swoop", "Canada", &airline_logo_WSW}
# { "WTA", "WEST TOGO", "Africa West", "Togo", nullptr}
# { "WTC", "WATCO", "Weasua Air Transport Company", "Liberia", nullptr}
# { "WTF", "WESTAF AIRTRANS", "West African Air Transport", "Senegal", nullptr}
# { "WTN", "TARNISH", "BAE Systems", "United Kingdom", nullptr}
# { "WTP", "WESTPOINT", "Westpoint Air", "Canada", nullptr}
# { "WTV", "WESTAVIA", "Western Aviators", "United States", nullptr}
# { "WUK", "WIZZ GO", "Wizz Air UK", "United Kingdom", nullptr}
# { "WVA", "WABASH VALLEY", "Hand D Aviation", "United States", nullptr}
# { "WVL", "WIZZBUL", "Wizz Air Bulgaria", "Bulgaria", nullptr}
# { "WWD", "WESTWARD", "Westward Airways", "United States", nullptr}
# { "WWG", "AERO-W", "Aereo WWG", "Mexico", nullptr}
# { "WWI", "WORLDWIDE", "Worldwide Jet Charter", "United States", nullptr}
# { "WWL", "", "Whyalla Airlines", "Australia", nullptr}
# { "WWM", "MANAS WING", "World Wing Aviation", "Kyrgyzstan", nullptr}
# { "WWS", "", "Worldwide Aviation Services", "Pakistan", nullptr}
# { "WWW", "JANET", "Janet", "United States", nullptr}
# { "WYC", "WYCOMBE", "Wycombe Air Centre", "United Kingdom", nullptr}
# { "WYG", "WYOMING", "Wyoming Airlines", "United States", nullptr}
# { "WYT", "WYTON", "2 Sqn No 1 Elementary Flying Training School", "United Kingdom", nullptr}
# { "WZP", "ZIPPER", "Zip", "Canada", nullptr}
# { "WZZ", "WIZZAIR", "Wizz Air", "Hungary", &airline_logo_WZZ}
# { "XAA", "", "Aeronautical Radio Inc", "United States", nullptr}
# { "XAB", "AERO XABRE", "Xabre Aerolineas", "Mexico", nullptr}
# { "XAC", "", "Air Charter World", "United States", nullptr}
# { "XAD", "", "Certified Air Dispatch", "United States", nullptr}
# { "XAE", "AURA", "Xair", "Czech Republic", nullptr}
# { "XAF", "", "Executive Air Fleet", "United States", nullptr}
# { "XAH", "", "Executive Aircraft Services", "United Kingdom", nullptr}
# { "XAK", "SUNEXPRESS", "Airkenya", "Kenya", nullptr}
# { "XAM", "ALLIANCE", "AMR Services Corporation", "United States", nullptr}
# { "XAO", "", "Airline Operations Services", "United States", nullptr}
# { "XAP", "MID-TOWN", "Direct Air trading asMidway Connection", "United States", nullptr}
# { "XAR", "XPRESS", "XpressAir", "Indonesia", nullptr}
# { "XAS", "", "PHH Aviation System", "United States", nullptr}
# { "XAT", "", "AT and T Aviation Division", "United States", nullptr}
# { "XAU", "PEARL", "Aerolink Uganda", "Uganda", nullptr}
# { "XAV", "AVIAPROM", "Aviaprom Enterprises", "Russia", nullptr}
# { "XAX", "XANADU", "AirAsia X", "Malaysia", nullptr}
# { "XBG", "", "City of Bangor", "United States", nullptr}
# { "XBO", "", "Baseops International", "United States", nullptr}
# { "XCA", "COLT", "Colt Transportes Aereos", "Brazil", nullptr}
# { "XCC", "XCALAK", "Ecoturistica de Xcalak", "Mexico", nullptr}
# { "XCL", "", "Contel ASC", "United States", nullptr}
# { "XCO", "", "Compuflight Operations Service", "United States", nullptr}
# { "XCS", "", "Compuserve Incorporated", "United States", nullptr}
# { "XCT", "AEROCOSTAXI", "Aero Costa Taxi Areo", "Mexico", nullptr}
# { "XCX", "", "Citibank", "United States", nullptr}
# { "XDA", "", "Bureau Veritas", "France", nullptr}
# { "XDD", "", "Lockheed DUATS", "United States", nullptr}
# { "XDS", "", "Dispatch Services", "United States", nullptr}
# { "XDT", "", "Date Transformation Corp", "United States", nullptr}
# { "XDY", "", "Dynair Services", "United States", nullptr}
# { "XEC", "", "Air Executive Charter", "Germany", nullptr}
# { "XEL", "HELI EXCEL", "Excel Charter", "United Kingdom", nullptr}
# { "XER", "XEROX", "Xerox Corporation", "United States", nullptr}
# { "XFA", "FAX AIR", "FlyAsianXpress", "Malaysia", nullptr}
# { "XFS", "", "American Flight Service Systems", "United States", nullptr}
# { "XFX", "AIRCORP", "Airways Corporation of New Zealand", "New Zealand", nullptr}
# { "XGA", "", "General Aviation Terminal", "Canada", nullptr}
# { "XGG", "", "IMP Group Aviation Services", "Canada", nullptr}
# { "XGS", "", "Global System", "United States", nullptr}
# { "XGW", "", "Global Weather Dynamics", "United States", nullptr}
# { "XJA", "", "Assistance Aeroportuaire de L'Aeroport de Paris", "France", nullptr}
# { "XJC", "EXCLUSIVE JET", "XJCLimited", "United Kingdom", nullptr}
# { "XJE", "", "X-Jet", "Austria", nullptr}
# { "XJT", "XRAY", "Xjet Limited", "United Kingdom", nullptr}
# { "XKA", "", "Kavouras Inc", "United States", nullptr}
# { "XKX", "", "ASECNA", "France", nullptr}
# { "XLA", "EXPO", "Excel Airways", "United Kingdom", nullptr}
# { "XLB", "", "Aircraft Performance Group", "United States", nullptr}
# { "XLD", "", "Jeppesen Data Plan", "United States", nullptr}
# { "XLG", "", "Lockheed Air Terminal", "United States", nullptr}
# { "XLK", "SAFARILINK", "Safarilink Aviation", "Kenya", nullptr}
# { "XLL", "TINGA-TINGA", "Air Excel", "Tanzania", nullptr}
# { "XLT", "INFRAERO", "Empressa Brasileira de Infra-Estrutura Aeroportuaria-Infraero", "Brazil", nullptr}
# { "XMA", "", "Martin Aviation Services", "United States", nullptr}
# { "XME", "AUS-CARGO", "Australian air Express", "Australia", nullptr}
# { "XMG", "", "AMS Group", "Russia", nullptr}
# { "XMR", "AUTHORITY", "Irish Aviation Authority", "Ireland", nullptr}
# { "XMS", "SANTA", "British Airways Santa", "United Kingdom", nullptr}
# { "XMX", "SENEAM", "SENEAM", "Mexico", nullptr}
# { "XNA", "EXPRESSNET", "Express Net Airlines", "United States", nullptr}
# { "XNC", "", "Canadian National Telecommunications", "Canada", nullptr}
# { "XNR", "TAXI NORTE", "Taxi Aero Del Norte", "Mexico", nullptr}
# { "XNS", "", "Navtech System Support", "Canada", nullptr}
# { "XNT", "", "Notams International", "United States", nullptr}
# { "XNV", "", "Navinc Airlines Services", "United States", nullptr}
# { "XOJ", "EXOJET", "XOJet", "United States", nullptr}
# { "XPA", "", "Pan Am Weather Systems", "United States", nullptr}
# { "XPE", "EXPERT", "Amira Air", "Austria", nullptr}
# { "XPG", "", "Southport Air Service", "United States", nullptr}
# { "XPL", "EXPRESSLINE", "Express Line Aircompany", "United States", nullptr}
# { "XPN", "", "Aero Express", "Niger", nullptr}
# { "XPR", "", "Air-Rep", "United States", nullptr}
# { "XPS", "XP PARCEL", "XP International", "Netherlands", nullptr}
# { "XPX", "", "Phoenix Flight Operations", "United States", nullptr}
# { "XRA", "INTENSIVE", "Intensive Air", "South Africa", nullptr}
# { "XRC", "", "Express Air Cargo", "Tunisia", nullptr}
# { "XRC", "TUNISIA CARGO", "Express Air Cargo", "Tunisia", nullptr}
# { "XRO", "CRAMER", "ExxAero", "Netherlands", &airline_logo_XRO}
# { "XSA", "", "Spectrum Air Service", "United States", nullptr}
# { "XSL", "EXCELAIRE", "Excel-Aire Service", "United States", nullptr}
# { "XSL", "SATSLAB", "Embry-Riddle Aeronautical University", "United States", nullptr}
# { "XSN", "", "Stephenville Aviation Services", "Canada", nullptr}
# { "XSR", "AIRSHARE", "Executive Flight Services", "United States", nullptr}
# { "XSS", "INTER EXPRESS", "Aero Express Intercontinental", "Mexico", nullptr}
# { "XTA", "TEXTRA", "Servicios Areos Textra", "Mexico", nullptr}
# { "XTJ", "", "Advance Aviation Services", "United States", nullptr}
# { "XTO", "EXPRESS TOURS", "Express Tours", "Canada", nullptr}
# { "XTR", "EXTER", "Sector Airlines", "Canada", nullptr}
# { "XWS", "", "WSI Corporation", "United States", nullptr}
# { "XWW", "", "World Weatherwatch", "Canada", nullptr}
# { "XXS", "", "Skyplan Services", "Canada", nullptr}
# { "XXV", "", "AASANA", "Bolivia", nullptr}
# { "XXX", "", "ASL (Air Service Liege)", "Belgium", nullptr}
# { "XYZ", "RAINBIRD", "Island Air Express", "United States", nullptr}
# { "YAK", "YAK AVIA", "Yakolev", "Russia", nullptr}
# { "YAK", "YAK AVIA", "Yakolev", "Russia", nullptr}
# { "YBE", "YELLOW BIRD", "Stewart Aviation Services", "United States", nullptr}
# { "YFS", "YOUNG AIR", "Young Flying Service", "United States", nullptr}
# { "YOG", "YOGAN AIR", "Central Aviation", "United States", nullptr}
# { "YRG", "YUGAIR", "Air Yugoslavia", "Serbia", nullptr}
# { "YRG", "YAKAIR GEORGIA", "Yak Air", "Georgia", nullptr}
# { "YWZ", "COAST AIR", "West Coast Air", "Canada", nullptr}
# { "YYY", "", "ICAO", "", nullptr}
# { "YZR", "YANGTZE RIVER", "Yangtze River Express", "China", nullptr}
# { "ZAI", "ZASAIR", "Zaire Aero Service", "Democratic Republic of Congo", nullptr}
# { "ZAK", "", "Airlink Zambia", "Zambia", nullptr}
# { "ZAK", "ZAMBIA SKIES", "Zambia Skyways", "Zambia", nullptr}
# { "ZAN", "ZANTOP", "Zantop International Airlines", "United States", nullptr}
# { "ZAR", "ZAIREAN", "Zairean Airlines", "Domocratic Republic of Congo", nullptr}
# { "ZAS", "ZAS AIRLINES", "ZAS Airlines of Egypt", "Egypt", nullptr}
# { "ZAV", "ZETAVIA", "Zetavia", "Ukraine", nullptr}
# { "ZAW", "ZED AIR", "Zoom Airways", "Bangladesh", nullptr}
# { "ZBA", "BOSKY", "Boskovic Air ChartersLimited", "Kenya", nullptr}
# { "ZMA", "ZAMBEZI WINGS", "Zambezi Airlines", "Zambia", nullptr}
# { "ZZM", "", "Agence Nationale des Aerodromes et de la Meteorologie", "Ivory Coast", nullptr}
# { "", "", "AmericanConnection", "United States", nullptr}
